# %% [markdown]
# <a href="https://colab.research.google.com/github/writezubair-cpu/ZAK-TEST_AI_Training/blob/main/Copy_of_weather_api_nov2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
response = requests.get("https://api.openweathermap.org/data/2.5/weather?q=Dubai&appid=79007029562c2ab46617d801d8018750&units=metric")
print(response.json())
# Out:
# {'coord': {'lon': 55.3047, 'lat': 25.2582}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 23.96, 'feels_like': 23.98, 'temp_min': 20.14, 'temp_max': 23.96, 'pressure': 1018, 'humidity': 60, 'sea_level': 1018, 'grnd_level': 1018}, 'visibility': 7000, 'wind': {'speed': 2.06, 'deg': 160}, 'clouds': {'all': 100}, 'dt': 1763439152, 'sys': {'type': 1, 'id': 7537, 'country': 'AE', 'sunrise': 1763433482, 'sunset': 1763472608}, 'timezone': 14400, 'id': 292223, 'name': 'Dubai', 'cod': 200}

# %%
import requests
import tkinter as tk
from tkinter import *
from PIL import Image, ImageTk

def get_weather(city):
    API_KEY = "YOUR_API_KEY_HERE"  # Replace with your valid rotated key
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"

    try:
        response = requests.get(url)
        response.raise_for_status()

        data = response.json()

        main = data.get("main", {})
        wind = data.get("wind", {})

        temperature = main.get("temp", "N/A")
        humidity = main.get("humidity", "N/A")
        max_temp = main.get("temp_max", "N/A")
        min_temp = main.get("temp_min", "N/A")
        wind_speed = wind.get("speed", "N/A")
        pressure = main.get("pressure", "N/A")
        sea_level = main.get("sea_level", "N/A")

        # Update GUI Labels
        temp_lbl.config(text=f"Temperature: {temperature}°C")
        hum_lbl.config(text=f"Humidity: {humidity}%")
        max_lbl.config(text=f"Max Temperature: {max_temp}°C")
        min_lbl.config(text=f"Min Temperature: {min_temp}°C")
        wind_lbl.config(text=f"Wind Speed: {wind_speed} m/s")
        press_lbl.config(text=f"Pressure: {pressure} hPa")
        sea_lbl.config(text=f"Sea Level: {sea_level} hPa")

    except requests.exceptions.HTTPError:
        temp_lbl.config(text="City not found or API error.")
    except requests.exceptions.RequestException:
        temp_lbl.config(text="Network error occurred.")


# ---------------- GUI Section ----------------

root = tk.Tk()
root.title("ZAK's Weather Dashboard")
root.geometry("800x600")

# ---------- Background Image ----------
bg_image = Image.open("background.jpg")   # ← Add your sea/beach image file
bg_image = bg_image.resize((900, 600))
bg_photo = ImageTk.PhotoImage(bg_image)

bg_label = Label(root, image=bg_photo)
bg_label.place(x=0, y=0, relwidth=1, relheight=1)

# ---------- Logo / Banner ----------
logo_image = Image.open("logo.png")   # ← Add your 'Welcome to Ab_
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /tmp/ipython-input-4070750812.py in <cell line: 0>()
#      42 # ---------------- GUI Section ----------------
#      43
# ---> 44 root = tk.Tk()
#      45 root.title("ZAK's Weather Dashboard")
#      46 root.geometry("800x600")
#
# /usr/lib/python3.12/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2347                 baseName = baseName + ext
#    2348         interactive = False
# -> 2349         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2350         if _debug:
#    2351             self.tk.settrace(_print_command)
#
# TclError: no display name and no $DISPLAY environment variable

# %%
import requests

def get_weather(Dubai):
   url = f"https://api.openweathermap.org/data/2.5/weather?q={Dubai}&appid=79007029562c2ab46617d801d8018750&units=metric"

   try:
       response= requests.get(url)
       weather_data = response.json()

       temperature = weather_data["main"]["temp"]
       humidity = weather_data["main"]["humidity"]
       max_temp = weather_data["main"]["temp_max"]
       min_temp = weather_data["main"]["temp_min"]
       wind_speed = weather_data["wind"]["speed"]
       pressure = weather_data["main"]["pressure"]
       humidity = weather_data["main"]["humidity"]
       sea_level = weather_data["main"]["sea_level"]


       print(f"Weather in {Dubai}:")
       print(f"Temperature {temperature}°C:")
       print(f"Humidity : {humidity}%")
       print(f"Max Temperature: {max_temp}°C:")
       print(f"Min Temperature: {min_temp}°C:")
       print(f"Wind Speed: {wind_speed} m/s:")
       print(f"Pressure: {pressure} hPa:")
       print(f"Sea Level: {sea_level} hPa:")
       print(f"Humidity: {humidity}%:")


   except requests.exceptions.RequestException:
        print("Error occured")


#usage
city_name = input("Enter the name of city:")
get_weather(city_name)
# Out:
# Enter the name of city:Abu Dhabi
# Weather in Abu Dhabi:
# Temperature 24.01°C:
# Humidity : 64%
# Max Temperature: 24.01°C:
# Min Temperature: 22.06°C:
# Wind Speed: 2.06 m/s:
# Pressure: 1019 hPa:
# Sea Level: 1019 hPa:
# Humidity: 64%:

# %%
pip install gradio

# %%
import gradio as gr
import requests

def get_weather(city):
    api_key = "YOUR_API_KEY"
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid=79007029562c2ab46617d801d8018750&units=metric"
    response = requests.get(url)
    data = response.json()
    if data["cod"] == 200:
        temp = data["main"]["temp"]
        description = data["weather"][0]["description"]
        return f"The current temperature in {city} is {temp}°C with {description}."
    else:
        return "Sorry, I couldn't find weather information for that city."

iface = gr.Interface(fn=get_weather, inputs="text", outputs="text")
iface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://73696375846bd89331.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://73696375846bd89331.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # Task
# To enhance the `get_weather` function in the Gradio interface, I will modify it to retrieve and display detailed weather information including temperature, humidity, max/min temperature, wind speed, pressure, and sea level, ensuring all these details are presented to the user.

# %% [markdown]
# ## Enhance Gradio Weather Function
#
# ### Subtask:
# Modify the `get_weather` function in the Gradio interface to retrieve and display detailed weather information, including temperature, humidity, max/min temperature, wind speed, pressure, and sea level, from the OpenWeatherMap API.

# %% [markdown]
# **Reasoning**:
# Modify the `get_weather` function to extract and display detailed weather information as specified in the instructions, then re-run the Gradio interface.

# %%
import requests
import tkinter as tk
from tkinter import *
from PIL import Image, ImageTk

def get_weather(city):
    API_KEY = "YOUR_API_KEY_HERE"  # Replace with your valid key
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"

    try:
        response = requests.get(url)
        response.raise_for_status()

        data = response.json()

        main = data.get("main", {})
        wind = data.get("wind", {})

        temperature = main.get("temp", "N/A")
        humidity = main.get("humidity", "N/A")
        max_temp = main.get("temp_max", "N/A")
        min_temp = main.get("temp_min", "N/A")
        wind_speed = wind.get("speed", "N/A")
        pressure = main.get("pressure", "N/A")
        sea_level = main.get("sea_level", "N/A")

        # Update GUI labels
        temp_lbl.config(text=f"Temperature: {temperature}°C")
        hum_lbl.config(text=f"Humidity: {humidity}%")
        max_lbl.config(text=f"Max Temperature: {max_temp}°C")
        min_lbl.config(text=f"Min Temperature: {min_temp}°C")
        wind_lbl.config(text=f"Wind Speed: {wind_speed} m/s")
        press_lbl.config(text=f"Pressure: {pressure} hPa")
        sea_lbl.config(text=f"Sea Level: {sea_level} hPa")

    except requests.exceptions.HTTPError:
        temp_lbl.config(text="City not found or API error.")
    except requests.exceptions.RequestException:
        temp_lbl.config(text="Network error occurred.")


# ---------------- GUI ----------------

root = tk.Tk()
root.title("ZAK's Weather Dashboard")
root.geometry("800x600")

root.configure(bg="#f4f4f4")  # simpl
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /tmp/ipython-input-1459458638.py in <cell line: 0>()
#      42 # ---------------- GUI ----------------
#      43
# ---> 44 root = tk.Tk()
#      45 root.title("ZAK's Weather Dashboard")
#      46 root.geometry("800x600")
#
# /usr/lib/python3.12/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2347                 baseName = baseName + ext
#    2348         interactive = False
# -> 2349         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2350         if _debug:
#    2351             self.tk.settrace(_print_command)
#
# TclError: no display name and no $DISPLAY environment variable

# %%
import gradio as gr
import requests

def get_weather(city):
    api_key = "YOUR_API_KEY" # It's better to use an environment variable for API keys, but for this exercise, we'll keep it inline.
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid=79007029562c2ab46617d801d8018750&units=metric"
    response = requests.get(url)
    data = response.json()
    if data["cod"] == 200:
        temp = data["main"]["temp"]
        description = data["weather"][0]["description"]
        humidity = data["main"]["humidity"]
        max_temp = data["main"]["temp_max"]
        min_temp = data["main"]["temp_min"]
        wind_speed = data["wind"]["speed"]
        pressure = data["main"]["pressure"]
        # Check if 'sea_level' exists before accessing it
        sea_level = data["main"].get("sea_level", "N/A") # Use .get() for optional keys

        return (
            f"The current temperature in {city} is {temp}°C with {description}. "
            f"Humidity: {humidity}%. Max Temp: {max_temp}°C. Min Temp: {min_temp}°C. "
            f"Wind Speed: {wind_speed} m/s. Pressure: {pressure} hPa. Sea Level: {sea_level} hPa."
        )
    else:
        return "Sorry, I couldn't find weather information for that city."

iface = gr.Interface(fn=get_weather, inputs="text", outputs="text")
iface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://d985c4f2e6829a541d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://d985c4f2e6829a541d.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Confirm the successful integration of detailed weather information into the Gradio interface and demonstrate its functionality.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   The `get_weather` function was successfully modified to retrieve and display additional weather details including humidity, maximum temperature, minimum temperature, wind speed, pressure, and sea level from the OpenWeatherMap API.
# *   The `.get()` method was used for the `sea_level` key to gracefully handle cases where this information might be missing from the API response, returning "N/A" in such instances.
# *   The Gradio interface was successfully re-launched with the enhanced `get_weather` function, providing comprehensive weather information as requested.
#
# ### Insights or Next Steps
# *   The enhanced Gradio interface now provides a more detailed and user-friendly weather information service, fulfilling the requirements of the task.
# *   For improved security and maintainability, the API key should ideally be stored as an environment variable rather than directly embedded in the code.
